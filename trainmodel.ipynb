# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
kushagrapandya_visdrone_dataset_path = kagglehub.dataset_download('kushagrapandya/visdrone-dataset')

print('Data source import complete.')
# Out:
# ...
# 100%|██████████| 2.10G/2.10G [00:24<00:00, 90.7MB/s]
# Extracting files...
# Data source import complete.

# %%
print(kushagrapandya_visdrone_dataset_path)
# Out:
# /root/.cache/kagglehub/datasets/kushagrapandya/visdrone-dataset/versions/1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install ultralytics
# !pip install torchvision torch
# !pip install pycocotools
# !pip install matplotlib opencv-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import torch.nn as nn
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolo26m.pt')

model.train(
    data='/content/VisDrone.yaml',
    project='/content/drive/MyDrive',
    epochs=30,
    batch = 4,
    imgsz=1024,
    optimizer='AdamW',
    lr0=0.001,
    momentum=0.937,
    weight_decay=0.0005,
    warmup_epochs=2,
    warmup_momentum=0.8,
    warmup_bias_lr=0.1,
    hsv_h=0.015, hsv_s=0.7, hsv_v=0.4,
    degrees=10,
    flipud=0.0,
    translate=0.1,
    scale=0.2,
    perspective=0.0005,
    fliplr=0.5,
    mosaic=0.2,
    close_mosaic=5,
    cos_lr=True,
    save=True,
    save_period=5,
    val=True,
    device=0,
    classes=[3, 4, 5, 7, 8, 9]   #в тг писали взять только эти классы (с трициклом)
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('/content/yolo26m30plus10ep.pt')

# %%
model.train(
    data='/content/VisDrone.yaml',
    project='/content/drive/MyDrive',
    epochs=20,
    batch = 2,
    imgsz=1600,
    optimizer='AdamW',
    lr0=0.0002,
    lrf = 0.1,
    momentum=0.937,
    weight_decay=0.0005,
    warmup_epochs=2,
    warmup_momentum=0.8,
    warmup_bias_lr=0.1,
    hsv_h=0.01, hsv_s=0.3, hsv_v=0.2,
    degrees=10,
    flipud=0.0,
    translate=0.1,
    scale=0.5,
    perspective=0.0005,
    fliplr=0.5,
    mosaic=0.02,
    close_mosaic=10,
    cos_lr=True,
    save=True,
    save_period=5,
    val=True,
    device=0,
    classes=[3, 4, 5, 7, 8, 9]   #в тг писали взять только эти классы (с трициклом)
)
# Out:
# Ultralytics 8.4.82 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
#после этого доучил в другом ноутбуке с resume = True, получлиось map@50 = 0.621, map@50-90 = 0.41

# %%
model = YOLO('/content/accurate.pt')

# %%
model.val(data = '/content/VisDrone.yaml', classes=[3, 4, 5, 7, 8, 9])
#итоговые метрики: map@50 = 0.622; map@50-90 = 0.411
#притом из логов видно: awning-tricycle модель определяет очень плохо: map@50 всего лишь 0.247
#без него map@50 = 0.6966
# Out:
# Ultralytics 8.4.84 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26m summary (fused): 132 layers, 20,357,162 parameters, 0 gradients, 67.9 GFLOPs
#
# WARNING ⚠️ Dataset '/content/VisDrone.yaml' images not found, missing path '/content/datasets/VisDrone/VisDrone2019-DET-val/images'
# ...
# Unzipping /content/datasets/VisDrone/VisDrone2019-DET-val.zip to /content/datasets/VisDrone/VisDrone2019-DET-val...: 100% ━━━━━━━━━━━━ 1099/1099 1.4Kfiles/s 0.8s
# Unzipping /content/datasets/VisDrone/VisDrone2019-DET-test-challenge.zip to /content/datasets/VisDrone/VisDrone2019-DET-test-challenge...: 100% ━━━━━━━━━━━━ 1582/1582 508.2files/s 3.1s
# Unzipping /content/datasets/VisDrone/VisDrone2019-DET-test-dev.zip to /content/datasets/VisDrone/VisDrone2019-DET-test-dev...: 100% ━━━━━━━━━━━━ 3223/3223 803.4files/s 4.0s
# ...

# %%
modelm = YOLO('/content/yolo26s.pt')
modelm.val(data = '/content/VisDrone.yaml', classes=[3, 4, 5, 7, 8, 9])
# Out:
# Ultralytics 8.4.84 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26s summary (fused): 122 layers, 9,469,050 parameters, 0 gradients, 20.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2696.5±407.6 MB/s, size: 204.1 KB)
# val: Scanning /content/datasets/VisDrone/VisDrone2019-DET-val/labels.cache... 548 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 548/548 164.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.3it/s 15.2s
#                    all        548      22458      0.602      0.511      0.529      0.341
#                    car        515      14064      0.775      0.828      0.852      0.589
#                    van        421       1975      0.562      0.532      0.535      0.369
#                  truck        266        750      0.551      0.433      0.433      0.286
# ...

# %%
import torch

# Вытаскиваем веса из внутренней PyTorch-модели
torch.save(model.model.state_dict(), 'yolov8ltry1cbam.pt')

# %%
from ultralytics import YOLO
import torch.nn as nn




# Eğitim ayarları
model.train(
    data='/content/VisDrone.yaml',
    epochs=20,
    batch = 4,
    imgsz=1024,
    optimizer='SGD',
    lr0=0.01,
    momentum=0.937,
    weight_decay=0.0005,
    warmup_epochs=5,
    warmup_momentum=0.8,
    warmup_bias_lr=0.1,
    hsv_h=0.015, hsv_s=0.7, hsv_v=0.4,
    degrees=15,
    flipud=0.0,
    translate=0.1,
    scale=0.5,
    shear=2,
    perspective=0.0005,
    fliplr=0.5,
    mosaic=1.0,
    mixup=0.4,
    close_mosaic=15,
    patience=50,
    cos_lr=True,
    save=True,
    save_period=1,
    val=True,
    resume = True,
    device=0,
    classes=[3, 4, 5, 7, 8, 9]   # <-- вот эта строка
)
# Out:
# WARNING ⚠️ model 'yolov8l.pt' is not a resumable training checkpoint (missing epoch/optimizer state). Use 'resume' only to continue incomplete training. Starting new training instead.
# Ultralytics 8.4.71 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import os
import random
import matplotlib.pyplot as plt
from ultralytics import YOLO
import cv2

model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')
test_image_dir = '/kaggle/input/visdrone-dataset/VisDrone2019-DET-test-dev/VisDrone2019-DET-test-dev/images'
test_images = os.listdir(test_image_dir)
test_images = [img for img in test_images if img.endswith('.jpg')]
sample_images = random.sample(test_images, 30)

fig, axes = plt.subplots(len(sample_images), 1, figsize=(10, len(sample_images) * 5))

for i, image_name in enumerate(sample_images):
    image_path = os.path.join(test_image_dir, image_name)
    img = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = model(image_path)
    axes[i].imshow(img_rgb)
    axes[i].axis('off')

    for pred in results[0].boxes:
        x1, y1, x2, y2 = pred.xyxy[0].cpu().numpy()
        conf = float(pred.conf.cpu().numpy())
        class_id = int(pred.cls.cpu().numpy())
        label = model.names[class_id]

        axes[i].add_patch(plt.Rectangle((x1, y1), x2 - x1, y2 - y1, fill=False, color='red', linewidth=2))
        axes[i].text(x1, y1, f'{label}: {conf:.2f}', color='white', fontsize=12, bbox=dict(facecolor='red', alpha=0.5))

plt.tight_layout()
plt.show()

# %%
import os
import random
import matplotlib.pyplot as plt
from ultralytics import YOLO
import cv2

model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')
test_image_dir = '/kaggle/input/visdrone-dataset/VisDrone2019-DET-test-dev/VisDrone2019-DET-test-dev/images'
test_images = os.listdir(test_image_dir)
test_images = [img for img in test_images if img.endswith('.jpg')]
sample_images = random.sample(test_images, 9)  # 9 sample images for a 3x3 grid

fig, axes = plt.subplots(3, 3, figsize=(15, 15))  # 3 rows and 3 columns of subplots
axes = axes.flatten()  # Flatten axes for easier indexing

for i, image_name in enumerate(sample_images):
    image_path = os.path.join(test_image_dir, image_name)
    img = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = model(image_path)

    axes[i].imshow(img_rgb)
    axes[i].axis('off')

    for pred in results[0].boxes:
        x1, y1, x2, y2 = pred.xyxy[0].cpu().numpy()
        conf = float(pred.conf.cpu().numpy())
        class_id = int(pred.cls.cpu().numpy())
        label = model.names[class_id]

        axes[i].add_patch(plt.Rectangle((x1, y1), x2 - x1, y2 - y1, fill=False, color='red', linewidth=2))
        axes[i].text(x1, y1, f'{label}: {conf:.2f}', color='white', fontsize=12, bbox=dict(facecolor='red', alpha=0.5))

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


img = mpimg.imread('/kaggle/working/runs/detect/train/F1_curve.png')  # Replace with your image path

plt.figure(figsize=(9, 6))

plt.imshow(img)
plt.axis('off')
plt.title('F1 Curve', fontsize=16)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


img = mpimg.imread('/kaggle/working/runs/detect/train/PR_curve.png')

plt.figure(figsize=(9, 6))

plt.imshow(img)
plt.axis('off')


plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


img = mpimg.imread('/kaggle/working/runs/detect/train/P_curve.png')

plt.figure(figsize=(9, 6))

plt.imshow(img)
plt.axis('off')


plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


img = mpimg.imread('/kaggle/working/runs/detect/train/R_curve.png')

plt.figure(figsize=(9, 6))

plt.imshow(img)
plt.axis('off')


plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


img = mpimg.imread('/kaggle/working/runs/detect/train/confusion_matrix.png')  # Replace with your image path

plt.figure(figsize=(12, 10))
plt.imshow(img)
plt.axis('off')


plt.show()
